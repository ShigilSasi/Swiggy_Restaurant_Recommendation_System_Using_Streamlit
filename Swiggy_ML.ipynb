# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/home/shigilsasi/code/Guvi_Projects/Swiggy_Restauraent_Recommendation_System/swiggy.csv")
df.head()
# Out:
#        id               name    city rating     rating_count   cost  \
# 0  567335     AB FOODS POINT  Abohar     --  Too Few Ratings  ₹ 200
# 1  531342  Janta Sweet House  Abohar    4.4      50+ ratings  ₹ 200
# 2  158203  theka coffee desi  Abohar    3.8     100+ ratings  ₹ 100
# 3  187912          Singh Hut  Abohar    3.7      20+ ratings  ₹ 250
# 4  543530      GRILL MASTERS  Abohar     --  Too Few Ratings  ₹ 250
#
#                       cuisine          lic_no  \
# 0            Beverages,Pizzas  22122652000138
# 1               Sweets,Bakery  12117201000112
# 2                   Beverages  22121652000190
# 3            Fast Food,Indian  22119652000167
# 4  Italian-American,Fast Food  12122201000053
#
#                                                 link  \
# 0  https://www.swiggy.com/restaurants/ab-foods-po...
# 1  https://www.swiggy.com/restaurants/janta-sweet...
# 2  https://www.swiggy.com/restaurants/theka-coffe...
# 3  https://www.swiggy.com/restaurants/singh-hut-n...
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# id               int64
# name            object
# city            object
# rating          object
# rating_count    object
# cost            object
# cuisine         object
# lic_no          object
# link            object
# address         object
# menu            object
# dtype: object

# %%
df.shape
# Out:
# (148541, 11)

# %%
df.isnull().sum()
# Out:
# id                0
# name             86
# city              0
# rating           86
# rating_count     86
# cost            131
# cuisine          99
# lic_no          229
# link              0
# address          86
# menu              0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#             id                                 name                  city  \
# 795     301904                        SHAKE IT BABY                  Agra
# 1299    358634  Meal Factory - By The Healthy Stove   Vastrapur,Ahmedabad
# 1303     77532              Shiv Shakti Kathiyawadi   Vastrapur,Ahmedabad
# 4242     93703                             Tomato'S  Chandkheda,Ahmedabad
# 4966    132295                          Chinese Hut                 Akola
# ...        ...                                  ...                   ...
# 147127  246351                WRAP IT - Eat Yummmm!        Gajuwaka,Vizag
# 147169   66873               Friends Tandoori Point        Gajuwaka,Vizag
# 147872  425369                           THE KURTOS    Dwarka Nagar,Vizag
# 147930  425304                    The Fritter Fries    Dwarka Nagar,Vizag
# 148271  148773                         Hashtag Cafe                Wardha
#
#        rating     rating_count   cost               cuisine          lic_no  \
# ...

# %%
df = df[df.notnull().all(axis=1)]

# %%
df.shape
# Out:
# (148255, 11)

# %%
df.isna().sum()
# Out:
# id              0
# name            0
# city            0
# rating          0
# rating_count    0
# cost            0
# cuisine         0
# lic_no          0
# link            0
# address         0
# menu            0
# dtype: int64

# %%
df['cost'] = df['cost'].str.replace('₹', '')
df['cost'] = pd.to_numeric(df['cost'], errors='coerce')

# %%
df.head()
# Out:
#        id               name    city rating     rating_count  cost  \
# 0  567335     AB FOODS POINT  Abohar     --  Too Few Ratings   200
# 1  531342  Janta Sweet House  Abohar    4.4      50+ ratings   200
# 2  158203  theka coffee desi  Abohar    3.8     100+ ratings   100
# 3  187912          Singh Hut  Abohar    3.7      20+ ratings   250
# 4  543530      GRILL MASTERS  Abohar     --  Too Few Ratings   250
#
#                       cuisine          lic_no  \
# 0            Beverages,Pizzas  22122652000138
# 1               Sweets,Bakery  12117201000112
# 2                   Beverages  22121652000190
# 3            Fast Food,Indian  22119652000167
# 4  Italian-American,Fast Food  12122201000053
#
#                                                 link  \
# 0  https://www.swiggy.com/restaurants/ab-foods-po...
# 1  https://www.swiggy.com/restaurants/janta-sweet...
# 2  https://www.swiggy.com/restaurants/theka-coffe...
# 3  https://www.swiggy.com/restaurants/singh-hut-n...
# ...

# %%
df.dtypes
# Out:
# id               int64
# name            object
# city            object
# rating          object
# rating_count    object
# cost             int64
# cuisine         object
# lic_no          object
# link            object
# address         object
# menu            object
# dtype: object

# %%
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')

# %%
df.isna().sum()
# Out:
# id                  0
# name                0
# city                0
# rating          86912
# rating_count        0
# cost                0
# cuisine             0
# lic_no              0
# link                0
# address             0
# menu                0
# dtype: int64

# %%
df['rating'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['rating'].skew()
# Out:
# np.float64(-0.9772708677920023)

# %%
df['rating'].value_counts()
# Out:
# rating
# 4.0    6524
# 4.1    6288
# 4.2    5811
# 3.8    5728
# 3.9    5428
# 4.3    5005
# 3.7    4239
# 4.4    3145
# 3.5    2958
# 3.6    2918
# 3.4    1878
# 3.3    1796
# 4.5    1775
# 4.6    1332
# 3.2    1199
# 3.0     858
# 3.1     790
# 4.7     648
# 2.8     473
# 2.9     471
# 4.8     338
# 2.7     325
# 2.5     220
# 5.0     209
# 2.6     207
# 4.9     172
# 2.3     128
# 2.4     118
# 2.2      89
# 2.0      72
# 2.1      61
# 1.9      46
# 1.8      27
# 1.5      18
# 1.6      17
# 1.7      13
# 1.4      10
# 1.2       4
# 1.3       3
# 1.1       1
# 1.0       1
# Name: count, dtype: int64

# %%
df['rating'].fillna(df['rating'].median(), inplace=True)

# %%
df.isna().sum()
# Out:
# id              0
# name            0
# city            0
# rating          0
# rating_count    0
# cost            0
# cuisine         0
# lic_no          0
# link            0
# address         0
# menu            0
# dtype: int64

# %%
df['rating_count'].value_counts()
# Out:
# rating_count
# Too Few Ratings    86912
# 20+ ratings        21604
# 100+ ratings       20514
# 50+ ratings        11985
# 500+ ratings        4390
# 1K+ ratings         2737
# 5K+ ratings           98
# 10K+ ratings          15
# Name: count, dtype: int64

# %%
cleaned_dataset = df.to_csv('cleaned_dataset.csv', index=False)

# %%
df.head()
# Out:
#        id               name    city  rating     rating_count  cost  \
# 0  567335     AB FOODS POINT  Abohar     4.0  Too Few Ratings   200
# 1  531342  Janta Sweet House  Abohar     4.4      50+ ratings   200
# 2  158203  theka coffee desi  Abohar     3.8     100+ ratings   100
# 3  187912          Singh Hut  Abohar     3.7      20+ ratings   250
# 4  543530      GRILL MASTERS  Abohar     4.0  Too Few Ratings   250
#
#                       cuisine          lic_no  \
# 0            Beverages,Pizzas  22122652000138
# 1               Sweets,Bakery  12117201000112
# 2                   Beverages  22121652000190
# 3            Fast Food,Indian  22119652000167
# 4  Italian-American,Fast Food  12122201000053
#
#                                                 link  \
# 0  https://www.swiggy.com/restaurants/ab-foods-po...
# 1  https://www.swiggy.com/restaurants/janta-sweet...
# 2  https://www.swiggy.com/restaurants/theka-coffe...
# 3  https://www.swiggy.com/restaurants/singh-hut-n...
# ...

# %%
df = df.drop(['id', 'lic_no', 'link', 'menu'], axis=1)  
df.head()
# Out:
#                 name    city  rating     rating_count  cost  \
# 0     AB FOODS POINT  Abohar     4.0  Too Few Ratings   200
# 1  Janta Sweet House  Abohar     4.4      50+ ratings   200
# 2  theka coffee desi  Abohar     3.8     100+ ratings   100
# 3          Singh Hut  Abohar     3.7      20+ ratings   250
# 4      GRILL MASTERS  Abohar     4.0  Too Few Ratings   250
#
#                       cuisine  \
# 0            Beverages,Pizzas
# 1               Sweets,Bakery
# 2                   Beverages
# 3            Fast Food,Indian
# 4  Italian-American,Fast Food
#
#                                              address
# 0  AB FOODS POINT, NEAR RISHI NARANG DENTAL CLINI...
# 1  Janta Sweet House, Bazar No.9, Circullar Road,...
# 2         theka coffee desi, sahtiya sadan road city
# 3    Singh Hut, CIRCULAR ROAD NEAR NEHRU PARK ABOHAR
# 4  GRILL MASTERS, ADA Heights, Abohar - Hanumanga...
